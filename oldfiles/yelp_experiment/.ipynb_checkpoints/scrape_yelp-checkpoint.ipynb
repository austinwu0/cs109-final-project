# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
import json
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

from pyquery import PyQuery as pq
from bs4 import BeautifulSoup
import requests
import random

# %%
url = "http://www.yelp.com/search?find_loc=95758&cflt=active"
get = requests.get(url)
soup = BeautifulSoup(get.text, "html.parser")
n = soup.find('span', attrs={"class": "pagination-results-window"}).text
int(n.replace('\n            Showing 1-10 of ','').replace('\n        ',''))
# Out:
# 287

# %%
categories = {
    #'total':'',
    'active':'&cflt=active',
    'beauty':'&cflt=beautysvc',
    'finserv':'&cflt=financialservices',
    #'homeserv':'&cflt=homeservices',
    'pets':'&cflt=pets',
    'religious':'&cflt=religiousorgs',
    'arts':'&cflt=arts',
    'education':'&cflt=education',
    'food':'&cflt=food',
    'travel':'&cflt=hotelstravel',
    'prof':'&cflt=professional',
    'restaurant':'&cflt=restaurants',
    'auto':'&cflt=auto',
    #'events':'&cflt=eventservices',
    'health':'&cflt=health',
    #'local':'&cflt=localservices',
    're':'&cflt=realestate',
    'shopping':'&cflt=shopping'
}

# %%
def nBusiness(zipcode, categoriesDict) :
    
    nBusinesses = {}
    
    url = "http://www.yelp.com/search?find_loc=" + str(zipcode)
    
    for category in categoriesDict :
        get = requests.get(url + categories[category])
        soup = BeautifulSoup(get.text, "html.parser")
        n = soup.find('span', attrs={"class": "pagination-results-window"}).text
        nBusinesses[category] = int(n.split()[-1])
    
    totalBusiness = float(sum(nBusinesses.values()))
    for category in categoriesDict :
        nBusinesses[category] = nBusinesses[category] / totalBusiness
    
    nBusinesses['zipcode'] = zipcode
    nBusinesses['total'] = totalBusiness
    
    return nBusinesses

def getCategories(zipcodeList, categoriesDict) :
    
    df = pd.DataFrame()
    
    for zipcode in zipcodeList :
        if len(str(zipcode)) < 5 :
            useZipCode = (5-len(str(zipcode)))*'0' + str(zipcode)
        else :
            useZipCode = zipcode
        results = nBusiness(useZipCode, categoriesDict)
        df=df.append(pd.DataFrame(results, columns=results.keys(), index=[0]))
    
    return df

# %%
zipcodeList = ['02138','95758','94116']

# %%
allZips = pd.read_csv('~/Google Drive/Current Classes/CS 109/Final Project/data/allDemographics2010.csv')['GEO.id2'][1:].tolist()

# %%
sampleZips = random.sample(allZips, 20)
sampledf = getCategories(sampleZips, categories)

# %%
sampledf
# Out:
#        arts  total  shopping    beauty  restaurant      food      auto    travel   finserv zipcode        re    health      pets    active      prof  education  religious
# 0  0.021772  21450  0.138228  0.047925    0.100839  0.076550  0.089697  0.036970  0.049650   18840  0.033147  0.166527  0.021352  0.029744  0.114545   0.040373   0.032681
# 0  0.022753  23909  0.123510  0.052951    0.095362  0.060521  0.066795  0.028107  0.052909   78201  0.060061  0.168388  0.009871  0.024175  0.175457   0.037894   0.021247
# 0  0.020147    546  0.014652  0.065934    0.106227  0.117216  0.027473  0.014652  0.106227   54841  0.087912  0.247253  0.029304  0.034799  0.012821   0.058608   0.056777
# 0  0.003003   1998  0.002503  0.009009    0.003003  0.922923  0.003504  0.002503  0.009510   16054  0.001502  0.003003  0.004004  0.010010  0.004004   0.003003   0.018519
