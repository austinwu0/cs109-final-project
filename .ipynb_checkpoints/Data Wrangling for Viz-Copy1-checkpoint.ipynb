# %%
import pickle
import pandas as pd
housing_data = pickle.load( open( "data/response_houses.pkl", "rb" ) )

# %%
housing_data.head()
# Out:
#    RegionName    agg_2011  agg_2015_adj  pct_delta
# 0       11368  373.833333    431.274105   1.153653
# 1       79936   80.333333     75.060164   0.934359
# 2       60629  107.166667    113.430961   1.058454
# 3       90650  228.750000    292.549418   1.278905
# 4       11226  309.166667    416.876846   1.348389

# %%
rental_data = pickle.load( open( "data/response_rental.pkl", "rb" ) )

# %%
rental_data.head()
# Out:
#    RegionName  agg_2011  agg_2015_adj  pct_delta
# 0       11368  1.868000      2.188278   1.171455
# 1       79936  0.744167      0.694379   0.933096
# 2       60629  1.197000      1.180207   0.985971
# 3       90650  1.524333      1.640026   1.075898
# 4       11226  1.014000      1.277783   1.260141

# %%
hr_ratio = pickle.load( open( "housing_rental_ratio.pkl", "rb" ) )

# %%
hr_ratio.head()
# Out:
#    RegionName  r_agg_2011  r_agg_2015_adj  r_pct_delta  h_agg_2011  \
# 0       11368    1.868000        2.188278     1.171455  373.833333
# 1       79936    0.744167        0.694379     0.933096   80.333333
# 2       60629    1.197000        1.180207     0.985971  107.166667
# 3       90650    1.524333        1.640026     1.075898  228.750000
# 4       11226    1.014000        1.277783     1.260141  309.166667
#
#    h_agg_2015_adj  h_pct_delta  ratio_2011  ratio_2015  ratio_pct_delta
# 0      431.274105     1.153653  200.124911  197.083754         0.984804
# 1       75.060164     0.934359  107.950728  108.096860         1.001354
# 2      113.430961     1.058454   89.529379   96.111037         1.073514
# 3      292.549418     1.278905  150.065602  178.380911         1.188686
# 4      416.876846     1.348389  304.898093  326.250103         1.070030

# %%
hr_ratio["ratio_2011"] = hr_ratio["h_agg_2011"]/(hr_ratio["r_agg_2011"] * 12)
hr_ratio["ratio_2015"] = hr_ratio["h_agg_2015_adj"]/(hr_ratio["r_agg_2015_adj"] * 12)

# %%
hr_ratio.head()
# Out:
#    RegionName  r_agg_2011  r_agg_2015_adj  r_pct_delta  h_agg_2011  \
# 0       11368    1.868000        2.188278     1.171455  373.833333
# 1       79936    0.744167        0.694379     0.933096   80.333333
# 2       60629    1.197000        1.180207     0.985971  107.166667
# 3       90650    1.524333        1.640026     1.075898  228.750000
# 4       11226    1.014000        1.277783     1.260141  309.166667
#
#    h_agg_2015_adj  h_pct_delta  ratio_2011  ratio_2015  ratio_pct_delta
# 0      431.274105     1.153653   16.677076   16.423646         0.984804
# 1       75.060164     0.934359    8.995894    9.008072         1.001354
# 2      113.430961     1.058454    7.460782    8.009253         1.073514
# 3      292.549418     1.278905   12.505467   14.865076         1.188686
# 4      416.876846     1.348389   25.408174   27.187509         1.070030

# %%
print hr_ratio[["ratio_2011"]].mean(axis=0)
print hr_ratio[["ratio_2011"]].median(axis=0)
print
print hr_ratio[["ratio_2015"]].mean(axis=0)
print hr_ratio[["ratio_2015"]].median(axis=0)
# Out:
# ratio_2011    10.837968
# dtype: float64
# ratio_2011    10.427802
# dtype: float64
#
# ratio_2015    11.207669
# dtype: float64
# ratio_2015    10.648011
# dtype: float64

# %%
srted = hr_ratio.sort('ratio_2011', ascending=False)
srted.head()
# Out:
#       RegionName  r_agg_2011  r_agg_2015_adj  r_pct_delta  h_agg_2011  \
# 8897       11363       1.036        1.250197     1.206754  444.916667
# 3747       11694       0.908        1.056780     1.163854  352.416667
# 83         11375       1.206        1.485387     1.231664  460.583333
# 88         11209       1.132        1.385447     1.223893  429.750000
# 47         11230       0.990        1.203380     1.215535  370.333333
#
#       h_agg_2015_adj  h_pct_delta  ratio_2011  ratio_2015  ratio_pct_delta
# 8897      470.452778     1.057395   35.788020   31.358575         0.876231
# 3747      326.887407     0.927559   32.343674   25.777003         0.796972
# 83        490.603687     1.065179   31.825825   27.523892         0.864829
# 88        497.631546     1.157956   31.636484   29.932065         0.946125
# 47        456.140904     1.231704   31.172840   31.587489         1.013302

# %%
srted_2015 = hr_ratio.sort('ratio_2015', ascending=False)
srted_2015.head()
# Out:
#       RegionName  r_agg_2011  r_agg_2015_adj  r_pct_delta  h_agg_2011  \
# 203        11225    0.916000        1.231439     1.344365  314.333333
# 47         11230    0.990000        1.203380     1.215535  370.333333
# 8897       11363    1.036000        1.250197     1.206754  444.916667
# 5439       94301    2.624333        3.648602     1.390297  806.750000
# 4673       94022    2.282667        3.055109     1.338395  697.250000
#
#       h_agg_2015_adj  h_pct_delta  ratio_2011  ratio_2015  ratio_pct_delta
# 203       472.771315     1.504044   28.596555   31.993159         1.118777
# 47        456.140904     1.231704   31.172840   31.587489         1.013302
# 8897      470.452778     1.057395   35.788020   31.358575         0.876231
# 5439     1332.383587     1.651545   25.617617   30.431374         1.187908
# 4673     1104.247454     1.583718   25.454512   30.120242         1.183297

# %%
hr_ratio = hr_ratio.rename(columns={'RegionName': 'zip'})
hr_ratio['zip'] = hr_ratio['zip'].astype(str)

newcountyCodes=pd.read_csv('addZipCodes/zip_to_county.csv', dtype={'ZCTA5': object, "GEOID" : object})
newcountyCodes = newcountyCodes.rename(columns={'ZCTA5': 'zip'})
newcountyCodes['zip'] = newcountyCodes['zip'].astype(str)
newcountyCodes.head()
# Out:
#      zip  STATE  COUNTY  GEOID
# 0  00601     72       1  72001
# 1  00601     72     141  72141
# 2  00602     72       3  72003
# 3  00603     72       5  72005
# 4  00606     72      93  72093

# %%
#processing zip codes
lst=[]
for i in hr_ratio["zip"]:
    if len(str(i))!=5:
        lst.append("0"+str(i))
    else:
        lst.append(str(i))
print len(hr_ratio["zip"])
print len(lst)
# Out:
# 11892
# 11892

# %%
for i in hr_ratio["zip"]:
    if len(str(i))!=5:
        print i
# Out:
# 8701
# 7087
# 7093
# 8753
# 7047
# 6010
# 7305
# 2301
# 2148
# 6516
# 2155
# 8854
# 2151
# 8527
# 6902
# 8861
# 7030
# 7728
# 8901
# 7083
# 1960
# 7306
# 6457
# 2124
# 2780
# 8053
# 6511
# 8831
# 6810
# 6492
# 2360
# 2169
# 7470
# 8816
# 1844
# 1201
# 3777
# 3255
# 6231
# 2670
# 3217
# 8328
# 3605
# 3810
# 2831
# 3084
# 8310
# 8738
# 6068
# 6235
# 1368
# 6027
# 1468
# 1474
# 3836
# 3284
# 6250
# 2808
# 3240
# 7737
# 7702
# 8311
# 2032
# 6754
# 3872
# 2763
# 6282
# 2827
# 8319
# 8326
# 1026
# 2468
# 6442
# 3226
# 6455
# 3227
# 3280
# 8542
# 3590
# 7865
# 3854
# 3464
# 6777
# 6778
# 2770
# 3465
# 1098
# 3282
# 7620
# 1366
# 1270
# 3450
# 2210
# 3268
# 3816
# 8802
# 7435
# 6782
# 1330
# 3837
# 1038
# 7847
# 8045
# 1537
# 3740
# 1096
# 3784
# 3875
# 3241
# 6794
# 7418
# 2630
# 6750
# 6021
# 6023
# 3846
# 7934
# 8867
# 7946
# 1083
# 7852
# 3224
# 3765
# 3813
# 1339
# 8061
# 3814
# 6039
# 3812
# 1338
# 8349
# 1344
# 2557
# 3245
# 8732
# 3243
# 1354
# 1008
# 1011
# 1034
# 1053
# 1503
# 3221
# 3230
# 3457
# 3574
# 3781
# 3838
# 3849
# 3855
# 3886
# 6481
# 6796
# 7933
# 8006
# 8067
# 8317
# 8345
# 8514
# 8887

# %%
db = pd.merge(hr_ratio, newcountyCodes, on='zip')
db.head()
# Out:
#      zip  r_agg_2011  r_agg_2015_adj  r_pct_delta  h_agg_2011  h_agg_2015_adj  \
# 0  11368    1.868000        2.188278     1.171455  373.833333      431.274105
# 1  79936    0.744167        0.694379     0.933096   80.333333       75.060164
# 2  60629    1.197000        1.180207     0.985971  107.166667      113.430961
# 3  90650    1.524333        1.640026     1.075898  228.750000      292.549418
# 4  11226    1.014000        1.277783     1.260141  309.166667      416.876846
#
#    h_pct_delta  ratio_2011  ratio_2015  ratio_pct_delta  STATE  COUNTY  GEOID
# 0     1.153653   16.677076   16.423646         0.984804     36      81  36081
# 1     0.934359    8.995894    9.008072         1.001354     48     141  48141
# 2     1.058454    7.460782    8.009253         1.073514     17      31  17031
# 3     1.278905   12.505467   14.865076         1.188686      6      37  06037
# 4     1.348389   25.408174   27.187509         1.070030     36      47  36047

# %%
newcountyCodes.shape
# Out:
# (44410, 4)

# %%
print min(db["h_agg_2011"])
print max(db["h_agg_2011"])
# Out:
# 19.5
# 1215.25

# %%
#for aggregating based on metric
import numpy as np
import json

def agg_metric(metric):
    gb = db[[metric, "GEOID"]].groupby("GEOID")
    medians = gb.agg([np.median])
    medians.head()
    
    #processing into json format
    lst = []
    for i in medians.iterrows():
        dct = {}
        dct["id"] = i[0]
        if np.isnan(i[1][0]):
            dct["value"] = None
        else:
            dct["value"] = i[1][0]
        lst.append(dct)
    
    for i in lst:
        if i["id"][0] == "0":
            i["id"] = i["id"][1:]
    
    import json
    fd=open("data/"+metric+".json","w")
    json.dump(lst, fd)
    fd.close()

    return medians, lst

# %%
medians, lst = agg_metric("ratio_pct_delta")

# %%
house_values = []
for i in medians.iterrows():
    if np.isnan(i[1][0]):
        house_values.append(np.nan)
    else:
        house_values.append(i[1][0])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
s=pd.Series(house_values)
plt.hist(s.dropna())
# Out:
# (array([  22.,  173.,  615.,  357.,  140.,   55.,   18.,    8.,    3.,    1.]),
#  array([ 0.72478201,  0.82680349,  0.92882497,  1.03084644,  1.13286792,
#          1.2348894 ,  1.33691088,  1.43893236,  1.54095383,  1.64297531,
#          1.74499679]),
#  <a list of 10 Patch objects>)

# %%
#get 2011 house price data
lst = []
for i in medians.iterrows():
    dct = {}
    dct["id"] = i[0]
    if np.isnan(i[1][0]):
        dct["value"] = None
    else:
        dct["value"] = i[1][0]
    lst.append(dct)

# %%
for i in lst:
    if i["id"] == "6053":
        print i

# %%
for i in lst:
    if i["id"][0] == "0":
        i["id"] = i["id"][1:]

# %%
import json
fd=open("data/houses_2011_3.json","w")
json.dump(lst, fd)
fd.close()

# %%
countyCodes=pd.read_csv('addZipCodes/US_FIPS_Codes.csv')
i = countyCodes[["FIPS State", "FIPS County"]]
FIPs = []
for row in i.iterrows():
    FIPs.append(('%02d' % row[1][0]) + ('%03d' % row[1][1]))

print FIPs
#countyCodes=countyCodes[['zip','county','state']]
# Out:
# ['01001', '01003', '01005', '01007', '01009', '01011', '01013', '01015', '01017', '01019', '01021', '01023', '01025', '01027', '01029', '01031', '01033', '01035', '01037', '01039', '01041', '01043', '01045', '01047', '01049', '01051', '01053', '01055', '01057', '01059', '01061', '01063', '01065', '01067', '01069', '01071', '01073', '01075', '01077', '01079', '01081', '01083', '01085', '01087', '01089', '01091', '01093', '01095', '01097', '01099', '01101', '01103', '01105', '01107', '01109', '01111', '01113', '01115', '01117', '01119', '01121', '01123', '01125', '01127', '01129', '01131', '01133', '02013', '02016', '02020', '02050', '02060', '02068', '02070', '02090', '02100', '02110', '02122', '02130', '02150', '02164', '02170', '02180', '02185', '02188', '02201', '02220', '02232', '02240', '02261', '02270', '02280', '02282', '02290', '04001', '04003', '04005', '04007', '04009', '04011', '04012', '04013', '04015', '04017', '04019', '04021', '04023', '04025', '04027', '05001', '05003', '05005', '05007', '05009', '05011', '05013', '05015', '05017', '05019', '05021', '05023', '05025', '05027', '05029', '05031', '05033', '05035', '05037', '05039', '05041', '05043', '05045', '05047', '05049', '05051', '05053', '05055', '05057', '05059', '05061', '05063', '05065', '05067', '05069', '05071', '05073', '05075', '05077', '05079', '05081', '05083', '05085', '05087', '05089', '05091', '05093', '05095', '05099', '05101', '05103', '05105', '05107', '05109', '05111', '05113', '05115', '05117', '05119', '05121', '05123', '05125', '05127', '05129', '05131', '05133', '05135', '05137', '05139', '05141', '05143', '05145', '05147', '05149', '06001', '06003', '06005', '06007', '06009', '06011', '06013', '06015', '06017', '06019', '06021', '06023', '06025', '06027', '06029', '06031', '06033', '06035', '06037', '06039', '06041', '06043', '06045', '06047', '06049', '06051', '06053', '06055', '06057', '06059', '06061', '06063', '06065', '06067', '06069', '06071', '06073', '06075', '06077', '06079', '06081', '06083', '06085', '06087', '06089', '06091', '06093', '06095', '06097', '06099', '06101', '06103', '06105', '06107', '06109', '06111', '06113', '06115', '08001', '08003', '08005', '08007', '08009', '08011', '08013', '08014', '08015', '08017', '08019', '08021', '08023', '08025', '08027', '08029', '08031', '08033', '08035', '08037', '08039', '08041', '08043', '08045', '08047', '08049', '08051', '08053', '08055', '08057', '08059', '08061', '08063', '08065', '08067', '08069', '08071', '08073', '08075', '08077', '08079', '08081', '08083', '08085', '08087', '08089', '08091', '08093', '08095', '08097', '08099', '08101', '08103', '08105', '08107', '08109', '08111', '08113', '08115', '08117', '08119', '08121', '08123', '08125', '09001', '09003', '09005', '09007', '09009', '09011', '09013', '09015', '10001', '10003', '10005', '11001', '11031', '12001', '12003', '12005', '12007', '12009', '12011', '12013', '12015', '12017', '12019', '12021', '12023', '12027', '12029', '12031', '12033', '12035', '12037', '12039', '12041', '12043', '12045', '12047', '12049', '12051', '12053', '12055', '12057', '12059', '12061', '12063', '12065', '12067', '12069', '12071', '12073', '12075', '12077', '12079', '12081', '12083', '12085', '12086', '12087', '12089', '12091', '12093', '12095', '12097', '12099', '12101', '12103', '12105', '12107', '12109', '12111', '12113', '12115', '12117', '12119', '12121', '12123', '12125', '12127', '12129', '12131', '12133', '13001', '13003', '13005', '13007', '13009', '13011', '13013', '13015', '13017', '13019', '13021', '13023', '13025', '13027', '13029', '13031', '13033', '13035', '13037', '13039', '13043', '13045', '13047', '13049', '13051', '13053', '13055', '13057', '13059', '13061', '13063', '13065', '13067', '13069', '13071', '13073', '13075', '13077', '13079', '13081', '13083', '13085', '13087', '13089', '13091', '13093', '13095', '13097', '13099', '13101', '13103', '13105', '13107', '13109', '13111', '13113', '13115', '13117', '13119', '13 ...

# %%
countyCodes["FIP_Code"] = FIPs

# %%
db.head()
# Out:
#      zip  r_agg_2011  r_agg_2015_adj  r_pct_delta  h_agg_2011  h_agg_2015_adj  \
# 0  11368    1.868000        2.188278     1.171455  373.833333      431.274105
# 1  79936    0.744167        0.694379     0.933096   80.333333       75.060164
# 2  60629    1.197000        1.180207     0.985971  107.166667      113.430961
# 3  90650    1.524333        1.640026     1.075898  228.750000      292.549418
# 4  11226    1.014000        1.277783     1.260141  309.166667      416.876846
#
#    h_pct_delta  ratio_2011  ratio_2015  ratio_pct_delta  STATE  COUNTY  GEOID
# 0     1.153653   16.677076   16.423646         0.984804     36      81  36081
# 1     0.934359    8.995894    9.008072         1.001354     48     141  48141
# 2     1.058454    7.460782    8.009253         1.073514     17      31  17031
# 3     1.278905   12.505467   14.865076         1.188686      6      37  06037
# 4     1.348389   25.408174   27.187509         1.070030     36      47  36047

# %%
county_srted = db.sort('STATE')
county_srted.head()
# Out:
#          zip  r_agg_2011  r_agg_2015_adj  r_pct_delta  h_agg_2011  \
# 6287   35022    0.679667        0.679719     1.000077   81.166667
# 11177  36530    0.630500        0.732369     1.161568   91.916667
# 4375   35211    0.555167        0.602636     1.085504   40.416667
# 6500   35950    0.555167        0.559602     1.007988   53.833333
# 9271   35476         NaN        0.663010          NaN   77.583333
#
#        h_agg_2015_adj  h_pct_delta  ratio_2011  ratio_2015  ratio_pct_delta  \
# 6287        80.721860     0.994520    9.951774    9.896478         0.994444
# 11177      100.169982     1.089791   12.148647   11.397947         0.938207
# 4375        38.022689     0.940768    6.066747    5.257833         0.866664
# 6500        52.006158     0.966059    8.080656    7.744523         0.958403
# 9271        75.868039     0.977891         NaN    9.535815              NaN
#
#        STATE  COUNTY  GEOID
# 6287       1     117  01117
# 11177      1       3  01003
# 4375       1      73  01073
# 6500       1      95  01095
# 9271       1     125  01125

# %%
newcountyCodes=pd.read_csv('addZipCodes/zip_to_county.csv', dtype={'ZCTA5': object, "GEOID" : object})
newcountyCodes = newcountyCodes.rename(columns={'ZCTA5': 'zip'})
newcountyCodes['zip'] = newcountyCodes['zip'].astype(str)
newcountyCodes.head()
# Out:
#      zip  STATE  COUNTY  GEOID
# 0  00601     72       1  72001
# 1  00601     72     141  72141
# 2  00602     72       3  72003
# 3  00603     72       5  72005
# 4  00606     72      93  72093

# %%
new_db = pd.merge(db, newcountyCodes, on='zip')
new_db = new_db.set_index('GEOID')
new_db.head()
# Out:
#      zip  r_agg_2011  r_agg_2015_adj  r_pct_delta  h_agg_2011  h_agg_2015_adj  \
# 0  11368    1.868000        2.188278     1.171455  373.833333      431.274105
# 1  79936    0.744167        0.694379     0.933096   80.333333       75.060164
# 2  60629    1.197000        1.180207     0.985971  107.166667      113.430961
# 3  90650    1.524333        1.640026     1.075898  228.750000      292.549418
# 4  11226    1.014000        1.277783     1.260141  309.166667      416.876846
#
#    h_pct_delta  ratio_2011  ratio_2015  ratio_pct_delta  STATE  COUNTY  GEOID
# 0     1.153653   16.677076   16.423646         0.984804     36      81  36081
# 1     0.934359    8.995894    9.008072         1.001354     48     141  48141
# 2     1.058454    7.460782    8.009253         1.073514     17      31  17031
# 3     1.278905   12.505467   14.865076         1.188686      6      37  06037
# 4     1.348389   25.408174   27.187509         1.070030     36      47  36047

# %%
new_db.shape
# Out:
# (15205, 15)

# %%
db.shape
# Out:
# (11890, 12)

# %%
new.head()
# Out:
#                r_agg_2011 r_agg_2015_adj r_pct_delta  h_agg_2011  \
#                    median         median      median      median
# county
# Ada County       0.644200       0.697531    1.118117   93.333333
# Adams County     0.825167       1.009647    1.202725  109.166667
# Addison County   0.796100       0.789590    0.991729  118.833333
# Aiken County     0.684167       0.602005    0.874249   59.750000
# Alachua County   0.726167       0.749551    1.048569   91.666667
#
#                h_agg_2015_adj h_pct_delta ratio_2011 ratio_2015  \
#                        median      median     median     median
# county
# Ada County         112.261841    1.202805  11.738270  12.832867
# Adams County       133.306010    1.271131  11.142530  11.290239
# Addison County     116.399739    0.979572  12.431342  12.276898
# Aiken County        62.541379    1.010112   7.349323   8.572077
# Alachua County      87.611789    0.988214  10.554065   9.918999
#
#                ratio_pct_delta  STATE COUNTY
#                         median median median
# county
# Ada County            1.078702     16      1
# Adams County          1.048249      8      1
# Addison County        0.987771     50      1
# Aiken County          1.136003     45      3
# Alachua County        0.928667     12      1

# %%
gb = new_db.groupby("GEOID")
new = gb.agg([np.median])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-d5e962d8bffb> in <module>()
# ----> 1 gb = new_db.groupby("GEOID")
#       2 new = gb.agg([np.median])
#
# /Users/annazhong/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3157         axis = self._get_axis_number(axis)
#    3158         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 3159                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    3160
#    3161     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /Users/annazhong/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1197         raise TypeError('invalid type: %s' % type(obj))
#    1198
# -> 1199     return klass(obj, by, **kwds)
#    1200
#    1201
#
# /Users/annazhong/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze)
#     386         if grouper is None:
#     387             grouper, exclusions, obj = _get_grouper(obj, keys, axis=axis,
# --> 388                                                     level=level, sort=sort)
#     389
#     390         self.obj = obj
#
# /Users/annazhong/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in _get_grouper(obj, key, axis, level, sort)
#    2146
#    2147         elif is_in_axis(gpr):  # df.groupby('name')
# -> 2148             in_axis, name, gpr = True, gpr, obj[gpr]
#    2149             exclusions.append(name)
#    2150
#
# /Users/annazhong/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Users/annazhong/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /Users/annazhong/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1082         res = cache.get(item)
#    1083         if res is None:
# -> 1084             values = self._data.get(item)
#    1085             res = self._box_item_values(item, values)
#    1086             cache[item] = res
#
# /Users/annazhong/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    2849
#    2850             if not isnull(item):
# -> 2851                 loc = self.items.get_loc(item)
#    2852             else:
#    2853                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/annazhong/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method)
#    1570         """
#    1571         if method is None:
# -> 1572             return self._engine.get_loc(_values_from_object(key))
#    1573
#    1574         indexer = self.get_indexer([key], method=method)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3824)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3704)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12280)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12231)()
#
# KeyError: 'GEOID'

# %%
new.head()
# Out:
#       r_agg_2011 r_agg_2015_adj r_pct_delta  h_agg_2011 h_agg_2015_adj  \
#           median         median      median      median         median
# GEOID
# 16001   0.644200       0.697531    1.118117   93.333333     112.261841
# 8045    0.825167       1.009647    1.202725  109.166667     133.306010
# 50001   0.796100       0.789590    0.991729  118.833333     116.399739
# 45003   0.684167       0.602005    0.874249   59.750000      62.541379
# 12001   0.726167       0.749551    1.048569   91.666667      87.611789
#
#       h_pct_delta ratio_2011 ratio_2015 ratio_pct_delta  STATE COUNTY
#            median     median     median          median median median
# GEOID
# 16001    1.202805  11.738270  12.832867        1.078702     16      1
# 8045     1.271131  11.142530  11.290239        1.048249      8      1
# 50001    0.979572  12.431342  12.276898        0.987771     50      1
# 45003    1.010112   7.349323   8.572077        1.136003     45      3
# 12001    0.988214  10.554065   9.918999        0.928667     12      1

# %%
for i in x.iterrows():
    print i[0]
#.to_json("data/houses_2011.json")
# Out:
# [ 16001.]
# [ 8045.]
# [ 50001.]
# [ 45003.]
# [ 12001.]
# [ 37017.]
# [ 6001.]
# [ 36001.]
# [ 37050.]
# [ 51510.]
# [ 24001.]
# [ 42003.]
# [ 18018.]
# [ 6005.]
# [ 45066.]
# [ 48005.]
# [ 24003.]
# [ 27003.]
# [ 48007.]
# [ 8005.]
# [ 51013.]
# [ 42063.]
# [ 22005.]
# [ 37099.]
# [ 53003.]
# [ 34001.]
# [ 37100.]
# [ 12003.]
# [ 1003.]
# [ 24510.]
# [ 24005.]
# [ 13138.]
# [ 25001.]
# [ 13135.]
# [ 26015.]
# [ 18005.]
# [ 13015.]
# [ 48149.]
# [ 12005.]
# [ 45013.]
# [ 22063.]
# [ 42007.]
# [ 47031.]
# [ 33001.]
# [ 48027.]
# [ 39013.]
# [ 16032.]
# [ 18164.]
# [ 34003.]
# [ 45015.]
# [ 42011.]
# [ 25003.]
# [ 26090.]
# [ 48029.]
# [ 13021.]
# [ 19013.]
# [ 18009.]
# [ 47009.]
# [ 27013.]
# [ 16019.]
# [ 21015.]
# [ 48099.]
# [ 22015.]
# [ 51023.]
# [ 8013.]
# [ 48037.]
# [ 12019.]
# [ 47011.]
# [ 48039.]
# [ 48041.]
# [ 12009.]
# [ 25005.]
# [ 36005.]
# [ 36007.]
# [ 8013.5]
# [ 12011.]
# [ 55009.]
# [ 37019.]
# [ 13029.]
# [ 42017.]
# [ 13031.]
# [ 37021.]
# [ 38015.]
# [ 34005.]
# [ 39017.]
# [ 6007.]
# [ 13151.]
# [ 37025.]
# [ 40023.]
# [ 22017.]
# [ 6009.]
# [ 22019.]
# [ 48055.]
# [ 50005.]
# [ 48238.]
# [ 55027.]
# [ 24009.]
# [ 34007.]
# [ 48061.]
# [ 21037.]
# [ 40017.]
# [ 47015.]
# [ 16027.]
# [ 34009.]
# [ 42025.]
# [ 24027.]
# [ 24021.]
# [ 32510.]
# [ 43552.]
# [ 37031.]
# [ 27019.]
# [ 30013.]
# [ 18085.]
# [ 37035.]
# [ 13295.]
# [ 36009.]
# [ 36011.]
# [ 24015.]
# [ 42027.]
# [ 48071.]
# [ 17019.]
# [ 24017.]
# [ 45019.]
# [ 12015.]
# [ 13051.]
# [ 36013.]
# [ 47029.]
# [ 53007.]
# [ 36015.]
# [ 36017.]
# [ 13092.]
# [ 51550.]
# [ 33005.]
# [ 42029.]
# [ 51041.]
# [ 55025.]
# [ 27025.]
# [ 50007.]
# [ 21133.]
# [ 32010.]
# [ 12017.]
# [ 41005.]
# [ 32003.]
# [ 13157.]
# [ 41007.]
# [ 29047.]
# [ 13063.]
# [ 8019.]
# [ 42033.]
# [ 39025.]
# [ 40027.]
# [ 26037.]
# [ 13067.]
# [ 4003.]
# [ 4005.]
# [ 47003.]
# [ 45029.]
# [ 12021.]
# [ 48085.]
# [ 41009.]
# [ 6011.]
# [ 48091.]
# [ 40031.]
# [ 6013.]
# [ 5029.]
# [ 17031.]
# [ 48097.]
# [ 33007.]
# [ 28077.]
# [ 36023.]
# [ 48099.]
# [ 39031.]
# [ 13077.]
# [ 53015.]
# [ 5033.]
# [ 40037.]
# [ 51080.]
# [ 39547.]
# [ 37053.]
# [ 41015.]
# [ 39035.]
# [ 13083.]
# [ 27037.]
# [ 48113.]
# [ 55025.]
# [ 39073.]
# [ 42043.]
# [ 47037.]
# [ 37059.]
# [ 49011.]
# [ 13117.]
# [ 18033.]
# [ 48149.]
# [ 28033.]
# [ 18029.]
# [ 18063.]
# [ 13089.]
# [ 42045.]
# [ 8029.]
# [ 48121.]
# [ 8031.]
# [ 19057.]
# [ 41017.]
# [ 12027.]
# [ 47043.]
# [ 11001.]
# [ 55027.]
# [ 35013.]
# [ 45019.]
# [ 13136.]
# [ 31055.]
# [ 19061.]
# [ 25007.]
# [ 17043.]
# [ 37061.]
# [ 37063.]
# [ 36027.]
# [ 12031.]
# [ 47049.]
# [ 8037.]
# [ 22033.]
# [ 48133.]
# [ 26055.]
# [ 55034.]
# [ 37065.]
# [ 45037.]
# [ 13103.]
# [ 6017.]
# [ 8041.]
# [ 8039.]
# [ 18039.]
# [ 48139.]
# [ 1051.]
# [ 40591.]
# [ 12033.]
# [ 25009.]
# [ 2090.]
# [ 51059.]
# [ 9001.]
# [ 51334.5]
# [ 48227.]
# [ 13111.]
# [ 5045.]
# [ 51061.]
# [ 21113.]
# [ 12035.]
# [ 30029.]
# [ 45041.]
# [ 13174.]
# [ 51065.]
# [ 55039.]
# [ 28067.]
# [ 13117.]
# [ 48157.]
# [ 39049.]
# [ 24021.]
# [ 51630.]
# [ 8043.]
# [ 6019.]
# [ 13121.]
# [ 12039.]
# [ 30031.]
# [ 48167.]
# [ 8045.]
# [ 5051.]
# [ 24023.]
# [ 37071.]
# [ 39055.]
# [ 36037.]
# [ 45043.]
# [ 47053.]
# [ 4007.]
# [ 12041.]
# [ 47055.]
# [ 13123.]
# [ 6021.]
# [ 34015.]
# [ 13127.]
# [ 51075.]
# [ 13129.]
# [ 40051.]
# [ 33009.]
# [ 4009.]
# [ 47057.]
# [ 38035.]
# [ 18169.]
# [ 37077.]
# [ 48286.]
# [ 53027.]
# [ 48181.]
# [ 55045.]
# [ 29225.]
# [ 45045.]
# [ 40055.]
# [ 48193.]
# [ 17091.]
# [ 48187.]
# [ 37081.]
# [ 12045.]
# [ 8051.]
# [ 13135.]
# [ 13137.]
# [ 48246.]
# [ 13139.]
# [ 47063.]
# [ 39061.]
# [ 25013.]
# [ 25015.]
# [ 51650.]
# [ 18059.]
# [ 51085.]
# [ 13143.]
# [ 21111.]
# [ 24025.]
# [ 37085.]
# [ 48201.]
# [ 48203.]
# [ 51412.5]
# [ 9003.]
# [ 48207.]
# [ 15001.]
# [ 37093.]
# [ 37149.]
# [ 18063.]
# [ 12051.]
# [ 27053.]
# [ 51087.]
# [ 15164.]
# [ 36053.]
# [ 12053.]
# [ 47081.]
# [ 48215.]
# [ 12055.]
# [ 48217.]
# [ 12057.]
# [ 26059.]
# [ 28049.]
# [ 39075.]
# [ 15003.]
# [ 48251.]
# [ 41027.]
# [ 48223.]
# [ 45051.]
# [ 13153.]
# [ 24027.]
# [ 34017.]
# [ 6023.]
# [ 47084.]
# [ 48231.]
# [ 34019.]
# [ 18124.]
# [ 39110.]
# [ 22045.]
# [ 6025.]
# [ 12061.]
# [ 42096.]
# [ 26065.]
# [ 6027.]
# [ 26067.]
# [ 37097.]
# [ 53029.]
# [ 28057.]
# [ 29095.]
# [ 51147.]
# [ 29097.]
# [ 21111.]
# [ 22051.]
# [ 16053.]
# [ 21113.]
# [ 20091.]
# [ 37101.]
# [ 19061.]
# [ 41033.]
# [ 26077.]
# [ 54039.]
# [ 17089.]
# [ 17091.]
# [ 48257.]
# [ 17093.]
# [ 55059.]
# [ 26081.]
# [ 21117.]
# [ 6029.]
# [ 45055.]
# [ 55045.]
# [ 53033.]
# [ 51146.]
# [ 36047.]
# [ 8094.]
# [ 53035.]
# [ 53037.]
# [ 41035.]
# [ 47093.]
# [ 4012.]
# [ 18091.]
# [ 42069.]
# [ 28071.]
# [ 18087.]
# [ 17097.]
# [ 28069.]
# [ 48076.]
# [ 42071.]
# [ 41039.]
# [ 56021.]
# [ 8069.]
# [ 6035.]
# [ 13175.]
# [ 18093.]
# [ 27131.]
# [ 42075.]
# [ 12071.]
# [ 42077.]
# [ 26091.]
# [ 12073.]
# [ 12075.]
# [ 53041.]
# [ 30046.]
# [ 45063.]
# [ 13183.]
# [ 39089.]
# [ 1089.]
# [ 41041.]
# [ 22061.]
# [ 19113.]
# [ 9005.]
# [ 48297.]
# [ 26093.]
# [ 40078.]
# [ 5085.]
# [ 39093.]
# [ 6037.]
# [ 47105.]
# [ 51107.]
# [ 51109.]
# [ 13185.]
# [ 48303.]
# [ 39095.]
# [ 13187.]
# [ 42079.]
# [ 32019.]
# [ 26099.]
# [ 37113.]
# [ 6039.]
# [ 17119.]
# [ 39099.]
# [ 51418.]
# [ 12081.]
# [ 55071.]
# [ 55073.]
# [ 4013.]
# [ 6041.]
# [ 55075.]
# [ 18097.]
# [ 6099.]
# [ 1095.]
# [ 12085.]
# [ 53045.]
# [ 2170.]
# [ 47119.]
# [ 48323.]
# [ 40087.]
# [ 48313.]
# [ 17111.]
# [ 17113.]
# [ 48309.]
# [ 47107.]
# [ 21093.]
# [ 37119.]
# [ 39103.]
# [ 47065.]
# [ 6045.]
# [ 6047.]
# [ 34021.]
# [ 13199.]
# [ 33013.]
# [ 8077.]
# [ 20121.]
# [ 12086.]
# [ 25017.]
# [ 27077.]
# [ 55079.]
# [ 46099.]
# [ 30063.]
# [ 1097.]
# [ 4015.]
# [ 34025.]
# [ 6051.]
# [ 54061.]
# [ 36055.]
# [ 6053.]
# [ 8083.]
# [ 39113.]
# [ 8085.]
# [ 37125.]
# [ 18081.]
# [ 34027.]
# [ 41051.]
# [ 13213.]
# [ 13215.]
# [ 26121.]
# [ 39119.]
# [ 40101.]
# [ 6055.]
# [ 37127.]
# [ 36059.]
# [ 56025.]
# [ 4017.]
# [ 48349.]
# [ 6057.]
# [ 10003.]
# [ 37129.]
# [ 9009.]
# [ 9011.]
# [ 36061.]
# [ 45071.]
# [ 44005.]
# [ 51700.]
# [ 15652.]
# [ 16069.]
# [ 36063.]
# [ 18113.]
# [ 48353.]
# [ 51710.]
# [ 25021.]
# [ 42095.]
# [ 42097.]
# [ 40105.]
# [ 48355.]
# [ 32023.]
# [ 26125.]
# [ 34029.]
# [ 45040.]
# [ 17103.]
# [ 13221.]
# [ 12091.]
# [ 12093.]
# [ 40109.]
# [ 36065.]
# [ 36067.]
# [ 37133.]
# [ 36069.]
# [ 12095.]
# [ 45075.]
# [ 36073.]
# [ 22071.]
# [ 12097.]
# [ 36075.]
# [ 35035.]
# [ 36077.]
# [ 39123.]
# [ 55087.]
# [ 55089.]
# [ 53038.]
# [ 12099.]
# [ 8093.]
# [ 48367.]
# [ 12101.]
# [ 34031.]
# [ 13223.]
# [ 13153.]
# [ 28077.]
# [ 37141.]
# [ 17143.]
# [ 42099.]
# [ 37106.]
# [ 29125.]
# [ 42101.]
# [ 39097.]
# [ 45007.]
# [ 53053.]
# [ 13293.]
# [ 4019.]
# [ 4021.]
# [ 12103.]
# [ 8048.]
# [ 37117.]
# [ 6061.]
# [ 22075.]
# [ 29165.]
# [ 6063.]
# [ 25023.]
# [ 13233.]
# [ 39133.]
# [ 18127.]
# [ 51740.]
# [ 18129.]
# [ 40125.]
# [ 28087.]
# [ 24033.]
# [ 51153.]
# [ 44007.]
# [ 8101.]
# [ 5119.]
# [ 36079.]
# [ 24035.]
# [ 36081.]
# [ 55101.]
# [ 27123.]
# [ 48381.]
# [ 37081.]
# [ 28121.]
# [ 22043.]
# [ 51061.]
# [ 36083.]
# [ 39077.]
# [ 51760.]
# [ 36085.]
# [ 18137.]
# [ 6065.]
# [ 47137.]
# [ 51770.]
# [ 51161.]
# [ 47147.]
# [ 37155.]
# [ 17161.]
# [ 13247.]
# [ 33015.]
# [ 36087.]
# [ 48314.]
# [ 40131.]
# [ 8107.]
# [ 37159.]
# [ 18047.]
# [ 48401.]
# [ 47037.]
# [ 50021.]
# [ 6067.]
# [ 23023.]
# [ 26145.]
# [ 34033.]
# [ 5125.]
# [ 45037.]
# [ 6069.]
# [ 6071.]
# [ 6073.]
# [ 6075.]
# [ 48407.]
# [ 6077.]
# [ 53055.]
# [ 6079.]
# [ 6081.]
# [ 48409.]
# [ 17167.]
# [ 6083.]
# [ 6085.]
# [ 6087.]
# [ 35049.]
# [ 12113.]
# [ 12115.]
# [ 36091.]
# [ 31153.]
# [ 55057.]
# [ 36093.]
# [ 36093.]
# [ 36097.]
# [ 42107.]
# [ 27049.]
# [ 48339.]
# [ 5131.]
# [ 20173.]
# [ 12117.]
# [ 36099.]
# [ 47155.]
# [ 6089.]
# [ 55083.]
# [ 20177.]
# [ 55117.]
# [ 47157.]
# [ 51171.]
# [ 27141.]
# [ 6093.]
# [ 53057.]
# [ 53059.]
# [ 48423.]
# [ 53061.]
# [ 6095.]
# [ 34035.]
# [ 48230.]
# [ 6097.]
# [ 13243.]
# [ 45083.]
# [ 21211.]
# [ 53063.]
# [ 51177.]
# [ 29183.]
# [ 22089.]
# [ 17163.]
# [ 55109.]
# [ 22092.]
# [ 12109.]
# [ 18141.]
# [ 36089.]
# [ 29510.]
# [ 29189.]
# [ 12111.]
# [ 24037.]
# [ 22103.]
# [ 51179.]
# [ 6099.]
# [ 37167.]
# [ 39151.]
# [ 18149.]
# [ 13128.]
# [ 36099.]
# [ 47161.]
# [ 37169.]
# [ 19169.]
# [ 33017.]
# [ 36103.]
# [ 36105.]
# [ 39153.]
# [ 47165.]
# [ 45061.]
# [ 37169.]
# [ 34037.]
# [ 6101.]
# [ 12121.]
# [ 24041.]
# [ 48276.]
# [ 48441.]
# [ 6103.]
# [ 8119.]
# [ 22109.]
# [ 53067.]
# [ 13277.]
# [ 41057.]
# [ 36107.]
# [ 18157.]
# [ 47162.]
# [ 9013.]
# [ 48451.]
# [ 36109.]
# [ 49045.]
# [ 13281.]
# [ 37137.]
# [ 13242.]
# [ 39155.]
# [ 6107.]
# [ 40143.]
# [ 6109.]
# [ 1125.]
# [ 39157.]
# [ 36111.]
# [ 41059.]
# [ 47171.]
# [ 34039.]
# [ 48315.]
# [ 13293.]
# [ 35061.]
# [ 26159.]
# [ 37077.]
# [ 18163.]
# [ 6111.]
# [ 18165.]
# [ 18167.]
# [ 51810.]
# [ 12127.]
# [ 40145.]
# [ 37183.]
# [ 12101.]
# [ 13295.]
# [ 53071.]
# [ 13214.]
# [ 55127.]
# [ 13299.]
# [ 34041.]
# [ 18173.]
# [ 49051.]
# [ 41067.]
# [ 32031.]
# [ 26161.]
# [ 37189.]
# [ 55133.]
# [ 55135.]
# [ 26163.]
# [ 47183.]
# [ 48479.]
# [ 49057.]
# [ 19187.]
# [ 8123.]
# [ 18069.]
# [ 22121.]
# [ 36119.]
# [ 42129.]
# [ 48481.]
# [ 53073.]
# [ 47091.]
# [ 13313.]
# [ 18113.]
# [ 48485.]
# [ 24045.]
# [ 48321.]
# [ 17197.]
# [ 51147.]
# [ 45066.]
# [ 48453.]
# [ 47189.]
# [ 51454.5]
# [ 9015.]
# [ 50027.]
# [ 17201.]
# [ 48499.]
# [ 19193.]
# [ 17203.]
# [ 25027.]
# [ 20209.]
# [ 53077.]
# [ 41071.]
# [ 36096.]
# [ 4025.]
# [ 30111.]
# [ 6113.]
# [ 42133.]
# [ 6115.]
# [ 4027.]

# %%
x.head()
# Out:
#            median
# GEOID
# 16001   93.333333
# 8045   109.166667
# 50001  118.833333
# 45003   59.750000
# 12001   91.666667
