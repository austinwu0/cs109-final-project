# %% [markdown]
# ## How to use Austin's cool county-zipcode mapping function

# %%
# %run addZipCodes/addZipCodes.py

# %%
addZipCodes('sample_convert.csv', 'temp.csv')
# Out:
# True

# %%
import pandas as pd

pd.read_csv('temp.csv').head(10)
# Out:
#    Unnamed: 0          GEO.id  GEO.id2        GEO.display-label  HD01_VD01  \
# 0           0  0500000US01003     1003  Baldwin County, Alabama      72896
# 1           1  0500000US01003     1003  Baldwin County, Alabama      72896
# 2           2  0500000US01003     1003  Baldwin County, Alabama      72896
# 3           3  0500000US01003     1003  Baldwin County, Alabama      72896
# 4           4  0500000US01003     1003  Baldwin County, Alabama      72896
# 5           5  0500000US01003     1003  Baldwin County, Alabama      72896
# 6           6  0500000US01003     1003  Baldwin County, Alabama      72896
# 7           7  0500000US01003     1003  Baldwin County, Alabama      72896
# 8           8  0500000US01003     1003  Baldwin County, Alabama      72896
# 9           9  0500000US01003     1003  Baldwin County, Alabama      72896
#
#    HD02_VD01  HD01_VD02  HD02_VD02  HD01_VD03  HD02_VD03  ...    HD02_VD10  \
# ...
